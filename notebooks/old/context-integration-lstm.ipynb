# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pathlib import Path
import seaborn as sns

# %%
import os
import sys

# %%
# chaging directory

# %%
root, *_ = !pwd

# %%
if root.endswith('notebooks'):
    os.chdir('../')
    root, *_ = !pwd
    sys.path.append('src/')

# %%
os.getcwd()
# Out:
# '/home/med/projects/competitions/mlb-kaggle'

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
RAW_PATH = Path(os.environ['RAW_PATH'])

# %%
PROCESSED_PATH = Path(os.environ['ROOT_DIR']) / 'processed'

# %%
os.listdir(RAW_PATH)
# Out:
# ['seasons.csv',
#  'teams.csv',
#  'example_sample_submission.csv',
#  'train_updated.csv',
#  'train.csv',
#  'mlb-player-digital-engagement-forecasting.zip',
#  'awards.csv',
#  'players.csv',
#  'example_test.csv',
#  'mlb',
#  'train_updated.csv.zip']

# %%
os.listdir(PROCESSED_PATH)
# Out:
# ['target.csv', 'context_raw_data.csv', 'raw_data.csv']

# %%
dates_cols = ['date', 'mlbDebutDate', 'DOB', 'rosterDate', 'pstatsDate']

# %%
df = pd.read_csv(PROCESSED_PATH / 'raw_data.csv',
                 parse_dates=dates_cols)

# %% [markdown]
# ### players data

# %%
# not all players are in the private test set
# the players in the test set are saved in the players.csv file

# %%
_players = pd.read_csv(RAW_PATH / 'players.csv')

# %%
_players['playerForTestSetAndFuturePreds'].fillna(False, inplace=True)

# %%
player_in_test = _players.query('playerForTestSetAndFuturePreds')['playerId']

# %%
# player_in_test holds only the players in the test set

# %% [markdown]
# ### filter players

# %%
from data.util import filter_by_date, filter_by_id

# %%
# filter only test players
df = filter_by_id(df, player_in_test)

# %%
# if you want to run on a sample,
# change sample_size to the number of players in the sample
sample_size = None

# %%
if sample_size is not None and sample_size > 0:
    df['target_avg'] = df[[f'target{i}' for i in range(1, 5)]].mean(axis=1)
    playerList = df.groupby(['playerId'])['target_avg'].std().sort_values(ascending=False).reset_index()
    df = filter_by_id(df, playerList['playerId'].head(sample_size))
    df.drop('target_avg', axis=1, inplace=True)

# %%
df.playerId.nunique()
# Out:
# 1187

# %%
# player stats

# %%
df.head()
# Out:
#    playerId   target1    target2   target3    target4       date  home  \
# 0    405395  0.151872  21.449416  0.112952  22.990196 2018-01-01   NaN
# 1    405395  0.136406  10.978585  0.096403  15.669173 2018-01-02   NaN
# 2    405395  0.064460   9.226190  0.101464  23.172829 2018-01-03   NaN
# 3    405395  0.024217  10.170965  0.102448  35.359116 2018-01-04   NaN
# 4    405395  0.157556   4.294307  0.046517  12.347789 2018-01-05   NaN
#
#   pstatsDate  battingOrder__ptvf  groundOuts__ptvf  ...  year  inSeason  \
# 0        NaT                 NaN               NaN  ...  2018     False
# 1        NaT                 NaN               NaN  ...  2018     False
# 2        NaT                 NaN               NaN  ...  2018     False
# 3        NaT                 NaN               NaN  ...  2018     False
# 4        NaT                 NaN               NaN  ...  2018     False
#
#    seasonPart        DOB  mlbDebutDate        birthCountry     weight  \
# 0   Offseason 1980-01-16    2001-04-02  Dominican Republic  106.59412
# 1   Offseason 1980-01-16    2001-04-02  Dominican Republic  106.59412
# 2   Offseason 1980-01-16    2001-04-02  Dominican Republic  106.59412
# 3   Offseason 1980-01-16    2001-04-02  Dominican Republic  106.59412
# 4   Offseason 1980-01-16    2001-04-02  Dominican Republic  106.59412
#
#    primaryPositionName  height  playerBMI
# 0           First Base   1.905  29.372661
# 1           First Base   1.905  29.372661
# 2           First Base   1.905  29.372661
# 3           First Base   1.905  29.372661
# 4           First Base   1.905  29.372661
#
# [5 rows x 98 columns]

# %%
list(df.columns)
# Out:
# ['playerId',
#  'target1',
#  'target2',
#  'target3',
#  'target4',
#  'date',
#  'home',
#  'pstatsDate',
#  'battingOrder__ptvf',
#  'groundOuts__ptvf',
#  'runsScored__ptvf',
#  'homeRuns__ptvf',
#  'strikeOuts__ptvf',
#  'baseOnBalls__ptvf',
#  'intentionalWalks__ptvf',
#  'hits__ptvf',
#  'hitByPitch__ptvf',
#  'stolenBases__ptvf',
#  'groundIntoTriplePlay__ptvf',
#  'plateAppearances__ptvf',
#  'totalBases__ptvf',
#  'rbi__ptvf',
#  'catchersInterference__ptvf',
#  'pickoffs__ptvf',
#  'gamesPlayedPitching__ptvf',
#  'gamesStartedPitching__ptvf',
#  'completeGamesPitching__ptvf',
#  'winsPitching__ptvf',
#  'lossesPitching__ptvf',
#  'groundOutsPitching__ptvf',
#  'runsPitching__ptvf',
#  'strikeOutsPitching__ptvf',
#  'atBatsPitching__ptvf',
#  'caughtStealingPitching__ptvf',
#  'inningsPitched__ptvf',
#  'saveOpportunities__ptvf',
#  'battersFaced__ptvf',
#  'outsPitching__ptvf',
#  'balks__ptvf',
#  'pickoffsPitching__ptvf',
#  'gamesFinishedPitching__ptvf',
#  'inheritedRunners__ptvf',
#  'catchersInterferencePitching__ptvf',
#  'sacBuntsPitching__ptvf',
#  'saves__ptvf',
#  'holds__ptvf',
#  'blownSaves__ptvf',
#  'assists__ptvf',
#  'putOuts__ptvf',
#  'chances__ptvf',
#  'SLG__ptvf',
#  'runsScored__date__maxNorm__ptvf',
#  'homeRuns__date__maxNorm__ptvf',
#  'hits__date__maxNorm__ptvf',
#  'SLG__date__maxNorm__ptvf',
#  'rbi__date__maxNorm__ptvf',
#  'runsPitching__date__maxNorm__ptvf',
#  'isTie',
#  'seriesDescription',
#  'currentGameInSeries',
#  'totalGamesVsoppTeam',
#  'playerTeamWinner',
#  'playerTeamScore',
#  'playerTeamWinPctAsHome',
#  'playerTeamWinPctAsAway',
#  'playerTeamWintPctHist',
#  'opponentTeamId',
#  'opponentTeamScore',
#  'opponentTeamWinPctAsHome',
#  'opponentTeamWinPctAsAway',
#  'rosterDate',
#  'teamId',
#  'status',
#  'numberOfFollowers',
#  'awardCount',
#  'teamFollowers',
#  'playerTeamWinpct',
#  'playerTeamDivisionchamp',
#  'playerTeamDivisionleader',
#  'playerTeamWildcardleader',
#  'playerTeamLasttenwins',
#  'playerTeamLasttenlosses',
#  'playerTeamXwinlosspct',
#  'playerTeamHomewinpct',
#  'playerTeamAwaywinpct',
#  'playerTeamHomewinpct__Date__Ranked',
#  'playerTeamAwaywinpct__Date__Ranked',
#  'playerTeamWinpct__Date__Ranked',
#  'year',
#  'inSeason',
#  'seasonPart',
#  'DOB',
#  'mlbDebutDate',
#  'birthCountry',
#  'weight',
#  'primaryPositionName',
#  'height',
#  'playerBMI']

# %% [markdown]
# ### preprocessing with pipelines

# %%
from typing import List
def forward_fill(df: pd.DataFrame, features: List[str],
                 on='playerId',
                 suffix: str = None,
                 limit: int =None):
    ffilled_df = df.groupby(on)[features].ffill(limit=limit)
    output_features = (features if suffix is None else
                       list(map(lambda f: suffix + f, features)))
    outputX = df.copy()
    outputX.loc[:, output_features] = ffilled_df.to_numpy()
    return outputX

# %%
def gen_hardcoded_features(df: pd.DataFrame):
    # some feature eng for the dates
    df['pstatsTime'] = (df['date'] - pd.to_datetime(df['pstatsDate'])).dt.total_seconds()
    df['playerAge'] = (df['date'] - df['DOB']).dt.total_seconds()
    df['playerTSinceDebut'] = (df['date'] - df['mlbDebutDate']).dt.total_seconds()
    df['playerDebutAge'] = (df['mlbDebutDate'] - df['DOB']).dt.total_seconds()
    df['rostersTime'] = (df['date'] - pd.to_datetime(df['rosterDate'])).dt.total_seconds()
    df[['rostersTime', 'pstatsTime']] /= 60 * 60 * 24
    # normalize
    df[['playerAge', 'playerTSinceDebut', 'playerDebutAge']] /= 60 * 60 * 24 * 365
#     df['AwardWinner'] = df['awardId'].isna().astype(np.float64)
    return df

# %%
def fillna(df: pd.DataFrame, fill_value=0):
    return df.fillna(fill_value)

# %%
from pipeline.core import FunctionTransformer, Pipeline, PdColumnTransformer, PdFeatureUnion
from pipeline.continuous import PdScaleNorm, FilterContinuousFeatures, MedianFillNaN
from pipeline.stats import StatisticGen, LagGen, FeaturesTable
from pipeline.categories import Categorify
from pipeline.season import join_season_info
from pipeline.players import join_players_info

# %%
last_ffill_features = ['gameType',
 'isTie',
 'gamesInSeries',
 'playerTeamWins',
 'playerTeamLosses',
 'playerTeamWinPct',
 'playerTeamWinner',
 'playerTeamScore',
 'opponentTeamWins',
 'opponentTeamLosses',
 'opponentTeamWinPct',
 'opponentTeamScore',
 'teamScoreDiff',
 'opponentTeamId']
                          
                          
inplace_ffill_features = ['numberOfFollowers',
                          'teamFollowers',
                          'status',
                          'teamId',
                          'rosterDate',
                          'pstatsDate']

# %%
# transformer for filling nan values with past valid values
# transformer for generating some hardcoded features
inplace_fill_forward_tmf = FunctionTransformer(forward_fill,
                                               kw_args={'features': inplace_ffill_features})
last_fill_forward_tmf = FunctionTransformer(forward_fill,
                                            kw_args={'features': last_ffill_features,
                                                     'suffix': 'last_'})
join_players_tmf = FunctionTransformer(join_players_info, kw_args={'path_to_players': RAW_PATH / 'players.csv'})
harcoded_feat_tmf = FunctionTransformer(gen_hardcoded_features)

# %%
# creating pipeline
ffill_and_gen_harcoded_feat = Pipeline([('inplace_fill_forward', inplace_fill_forward_tmf),
                                      #  ('last_fill_forward', last_fill_forward_tmf),
                                       ('hardcoded_feat', harcoded_feat_tmf)])

# %%
# features to use for target preprocessing
target_cols = ['target1', 'target2', 'target3', 'target4']
index_cols = ['date', 'playerId']
pp_cols = target_cols + index_cols

# %%
# categories encoding
categories = ['playerId', 'seasonPart', 'year', 'primaryPositionName',
              'status', 'teamId',
              'opponentTeamId', 'home', 'seriesDescription', 'currentGameInSeries']

categories_tmf = PdColumnTransformer([(category, Categorify(add_nan=True), category)
                                       for category in categories])

# %%
# for the statistics, we will compute them and then resuse them
stats_gen_tmf = StatisticGen(stats=['mean', 'median', 'std'], windows=[90], drop_index=False)
target_stats_tmf = PdColumnTransformer([('gen_stats', stats_gen_tmf, pp_cols)])
target_stats_table = target_stats_tmf.fit_transform(df)

# %%
target_stats_table.head()
# Out:
#    playerId       date  target1__mean__90d  target1__median__90d  \
# 0    405395 2018-01-01            0.151872              0.151872
# 1    405395 2018-01-02            0.144139              0.144139
# 2    405395 2018-01-03            0.117580              0.136406
# 3    405395 2018-01-04            0.094239              0.100433
# 4    405395 2018-01-05            0.106902              0.136406
#
#    target1__std__90d  target2__mean__90d  target2__median__90d  \
# 0                NaN           21.449417             21.449417
# 1           0.010936           16.214001             16.214001
# 2           0.046648           13.884730             10.978585
# 3           0.060248           12.956289             10.574775
# 4           0.059365           11.223893             10.170965
#
#    target2__std__90d  target3__mean__90d  target3__median__90d  \
# 0                NaN            0.112952              0.112952
# 1           7.403996            0.104677              0.104677
# 2           6.609544            0.103606              0.101464
# 3           5.707194            0.103317              0.101956
# 4           6.279732            0.091957              0.101464
#
#    target3__std__90d  target4__mean__90d  target4__median__90d  \
# 0                NaN           22.990196             22.990196
# 1           0.011702           19.329685             19.329685
# 2           0.008480           20.610733             22.990196
# 3           0.006948           24.297829             23.081512
# 4           0.026104           21.907820             22.990196
#
#    target4__std__90d
# 0                NaN
# 1           5.176745
# 2           4.280490
# 3           8.160501
# 4           8.860362

# %%
## merge computed statistics
reuse_computed_stats = Pipeline([('merge_stats', FeaturesTable(target_stats_table, lags=[60], clip_max=True)),
                                 ('fillnan', FunctionTransformer(fillna)),
                                 ('normalize', PdScaleNorm())
                                ])

# %%
# for continuous features, we will filter them and then fill nan values and normalize them

median_fillnan_columns = ['numberOfFollowers', 'teamFollowers',
                          'playerDebutAge', 'playerAge', 'playerTSinceDebut']
fillnan_median_tmf = MedianFillNaN(median_fillnan_columns)

# get the rest of the continuous features
continuous_feat_tmf = Pipeline([('get_cont_feat', FilterContinuousFeatures(ignore_features=categories +
                                                                           pp_cols +
                                                                           ['target_avg'])),
                                ('fillnan_median', fillnan_median_tmf),
                                ('fillnan', FunctionTransformer(fillna)),
                                ('normalize', PdScaleNorm())
                               ])

# %%
# putting all features generation steps together
all_features_tmf = PdFeatureUnion([('stats', reuse_computed_stats), 
                                   ('cont_feat', continuous_feat_tmf), 
                                  ('cats', categories_tmf),
                                  ])

# %%
# main pipeline with all steps 
pipeline = Pipeline([('core_features', ffill_and_gen_harcoded_feat),
                     ('features_generation', all_features_tmf)])

# %%
pipeline
# Out:
# Pipeline(steps=[('core_features',
#                  Pipeline(steps=[('inplace_fill_forward',
#                                   FunctionTransformer(func=<function forward_fill at 0x7f1ba1debca0>,
#                                                       kw_args={'features': ['numberOfFollowers',
#                                                                             'teamFollowers',
#                                                                             'status',
#                                                                             'teamId',
#                                                                             'rosterDate',
#                                                                             'pstatsDate']})),
#                                  ('hardcoded_feat',
#                                   FunctionTransformer(func=<function gen_hardcoded_features at 0x7f1b9c3f50d0>))])),
#                 ('features_...
#                                                                                       'primaryPositionName'),
#                                                                                      ('status',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'status'),
#                                                                                      ('teamId',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'teamId'),
#                                                                                      ('opponentTeamId',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'opponentTeamId'),
#                                                                                      ('home',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'home'),
#                                                                                      ('seriesDescription',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'seriesDescription'),
#                                                                                      ('currentGameInSeries',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'currentGameInSeries')]))]))])

# %%
from data.split import SplitData

# %%
# split the data on 2021-03-01 with a valid ds of 61 days
sp = SplitData("2021-04-01", test_days=500)

# %%
train_idx = sp.train_idx(df)
valid_idx = sp.valid_idx(df)

# %%
# %%time
# train the pipeline only with the train dataset
pipeline.fit(sp.filter(df, train_idx))
# Out:
# CPU times: user 15.4 s, sys: 2.39 s, total: 17.8 s
# Wall time: 17.8 s
# Pipeline(steps=[('core_features',
#                  Pipeline(steps=[('inplace_fill_forward',
#                                   FunctionTransformer(func=<function forward_fill at 0x7f1ba1debca0>,
#                                                       kw_args={'features': ['numberOfFollowers',
#                                                                             'teamFollowers',
#                                                                             'status',
#                                                                             'teamId',
#                                                                             'rosterDate',
#                                                                             'pstatsDate']})),
#                                  ('hardcoded_feat',
#                                   FunctionTransformer(func=<function gen_hardcoded_features at 0x7f1b9c3f50d0>))])),
#                 ('features_...
#                                                                                       'primaryPositionName'),
#                                                                                      ('status',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'status'),
#                                                                                      ('teamId',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'teamId'),
#                                                                                      ('opponentTeamId',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'opponentTeamId'),
#                                                                                      ('home',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'home'),
#                                                                                      ('seriesDescription',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'seriesDescription'),
#                                                                                      ('currentGameInSeries',
#                                                                                       Categorify(add_nan=True),
#                                                                                       'currentGameInSeries')]))]))])

# %%
# %%time
# transform all dataset
features = pipeline.transform(df)
# Out:
# CPU times: user 15.7 s, sys: 2.61 s, total: 18.4 s
# Wall time: 18.4 s

# %%
pd.options.display.max_rows = len(features.columns)
features.T.head(len(features.columns))
# Out:
#                                      0         1         2         3        \
# target1__mean__90d__60lag           0.000000  0.000000  0.000000  0.000000
# target1__median__90d__60lag         0.000000  0.000000  0.000000  0.000000
# target1__std__90d__60lag            0.000000  0.000000  0.000000  0.000000
# target2__mean__90d__60lag           0.000000  0.000000  0.000000  0.000000
# target2__median__90d__60lag         0.000000  0.000000  0.000000  0.000000
# target2__std__90d__60lag            0.000000  0.000000  0.000000  0.000000
# target3__mean__90d__60lag           0.000000  0.000000  0.000000  0.000000
# target3__median__90d__60lag         0.000000  0.000000  0.000000  0.000000
# target3__std__90d__60lag            0.000000  0.000000  0.000000  0.000000
# target4__mean__90d__60lag           0.000000  0.000000  0.000000  0.000000
# target4__median__90d__60lag         0.000000  0.000000  0.000000  0.000000
# target4__std__90d__60lag            0.000000  0.000000  0.000000  0.000000
# battingOrder__ptvf                  0.000000  0.000000  0.000000  0.000000
# groundOuts__ptvf                    0.000000  0.000000  0.000000  0.000000
# runsScored__ptvf                    0.000000  0.000000  0.000000  0.000000
# homeRuns__ptvf                      0.000000  0.000000  0.000000  0.000000
# strikeOuts__ptvf                    0.000000  0.000000  0.000000  0.000000
# baseOnBalls__ptvf                   0.000000  0.000000  0.000000  0.000000
# intentionalWalks__ptvf              0.000000  0.000000  0.000000  0.000000
# hits__ptvf                          0.000000  0.000000  0.000000  0.000000
# hitByPitch__ptvf                    0.000000  0.000000  0.000000  0.000000
# stolenBases__ptvf                   0.000000  0.000000  0.000000  0.000000
# groundIntoTriplePlay__ptvf          0.000000  0.000000  0.000000  0.000000
# plateAppearances__ptvf              0.000000  0.000000  0.000000  0.000000
# totalBases__ptvf                    0.000000  0.000000  0.000000  0.000000
# rbi__ptvf                           0.000000  0.000000  0.000000  0.000000
# catchersInterference__ptvf          0.000000  0.000000  0.000000  0.000000
# pickoffs__ptvf                      0.000000  0.000000  0.000000  0.000000
# gamesPlayedPitching__ptvf           0.000000  0.000000  0.000000  0.000000
# gamesStartedPitching__ptvf          0.000000  0.000000  0.000000  0.000000
# completeGamesPitching__ptvf         0.000000  0.000000  0.000000  0.000000
# winsPitching__ptvf                  0.000000  0.000000  0.000000  0.000000
# lossesPitching__ptvf                0.000000  0.000000  0.000000  0.000000
# groundOutsPitching__ptvf            0.000000  0.000000  0.000000  0.000000
# runsPitching__ptvf                  0.000000  0.000000  0.000000  0.000000
# strikeOutsPitching__ptvf            0.000000  0.000000  0.000000  0.000000
# atBatsPitching__ptvf                0.000000  0.000000  0.000000  0.000000
# caughtStealingPitching__ptvf        0.000000  0.000000  0.000000  0.000000
# inningsPitched__ptvf                0.000000  0.000000  0.000000  0.000000
# saveOpportunities__ptvf             0.000000  0.000000  0.000000  0.000000
# battersFaced__ptvf                  0.000000  0.000000  0.000000  0.000000
# outsPitching__ptvf                  0.000000  0.000000  0.000000  0.000000
# balks__ptvf                         0.000000  0.000000  0.000000  0.000000
# pickoffsPitching__ptvf              0.000000  0.000000  0.000000  0.000000
# gamesFinishedPitching__ptvf         0.000000  0.000000  0.000000  0.000000
# inheritedRunners__ptvf              0.000000  0.000000  0.000000  0.000000
# catchersInterferencePitching__ptvf  0.000000  0.000000  0.000000  0.000000
# sacBuntsPitching__ptvf              0.000000  0.000000  0.000000  0.000000
# saves__ptvf                         0.000000  0.000000  0.000000  0.000000
# holds__ptvf                         0.000000  0.000000  0.000000  0.000000
# blownSaves__ptvf                    0.000000  0.000000  0.000000  0.000000
# assists__ptvf                       0.000000  0.000000  0.000000  0.000000
# putOuts__ptvf                       0.000000  0.000000  0.000000  0.000000
# chances__ptvf                       0.000000  0.000000  0.000000  0.000000
# SLG__ptvf                           0.166667  0.166667  0.166667  0.166667
# runsScored__date__maxNorm__ptvf     0.000000  0.000000  0.000000  0.000000
# homeRuns__date__maxNorm__ptvf       0.000000  0.000000  0.000000  0.000000
# hits__date__maxNorm__ptvf           0.000000  0.000000  0.000000  0.000000
# SLG__date__maxNorm__ptvf            0.500000  0.500000  0.500000  0.500000
# rbi__date__maxNorm__ptvf            0.000000  0.000000  0.000000  0.000000
# runsPitching__date__maxNorm__ptvf   0.000000  0.000000  0.000000  0.000000
# isTie                               0.000000  0.000000  0.000000  0.000000
# totalGamesVsoppTeam                 0.000000  0.000000  0.000000  0.000000
# playerTeamScore                     0.000000  0.000000  0.000000  0.000000
# playerTeamWinPctAsHome              0.000000  0.000000  0.000000  0.000000
# playerTeamWinPctAsAway              0.000000  0.000000  0.000000  0.000000
# playerTeamWintPctHist               0.000000  0.000000  0.000000  0.000000
# opponentTeamScore                   0.000000  0.000000  0.000000  0.000000
# opponentTeamWinPctAsHome            0.000000  0.000000  0.000000  0.000000
# opponentTeamWinPctAsAway            0.000000  0.000000  0.000000  0.000000
# numberOfFollowers                   0.076515  0.076515  0.076515  0.076515
# awardCount                          0.000000  0.000000  0.000000  0.000000
# teamFollowers                       0.201653  0.201653  0.201653  0.201653
# playerTeamWinpct                    0.000000  0.000000  0.000000  0.000000
# playerTeamDivisionchamp             0.000000  0.000000  0.000000  0.000000
# playerTeamDivisionleader            0.000000  0.000000  0.000000  0.000000
# playerTeamLasttenwins               0.000000  0.000000  0.000000  0.000000
# playerTeamLasttenlosses             0.000000  0.000000  0.000000  0.000000
# playerTeamXwinlosspct               0.000000  0.000000  0.000000  0.000000
# playerTeamHomewinpct                0.000000  0.000000  0.000000  0.000000
# playerTeamAwaywinpct                0.000000  0.000000  0.000000  0.000000
# playerTeamHomewinpct__Date__Ranked  0.000000  0.000000  0.000000  0.000000
# playerTeamAwaywinpct__Date__Ranked  0.000000  0.000000  0.000000  0.000000
# playerTeamWinpct__Date__Ranked      0.000000  0.000000  0.000000  0.000000
# weight                              0.641221  0.641221  0.641221  0.641221
# height                              0.562500  0.562500  0.562500  0.562500
# playerBMI                           0.473144  0.473144  0.473144  0.473144
# pstatsTime                          0.000000  0.000000  0.000000  0.000000
# playerAge                           0.862385  0.862501  0.862618  0.862734
# playerTSinceDebut                   0.861339  0.861456  0.861573  0.861690
# playerDebutAge                      0.123216  0.123216  0.123216  0.123216
# rostersTime                         0.000000  0.000000  0.000000  0.000000
# playerId                            1.000000  1.000000  1.000000  1.000000
# seasonPart                          3.000000  3.000000  3.000000  3.000000
# year                                1.000000  1.000000  1.000000  1.000000
# primaryPositionName                 3.000000  3.000000  3.000000  3.000000
# status                              3.000000  3.000000  3.000000  3.000000
# teamId                              1.000000  1.000000  1.000000  1.000000
# opponentTeamId                      0.000000  0.000000  0.000000  0.000000
# home                                0.000000  0.000000  0.000000  0.000000
# seriesDescription                   0.000000  0.000000  0.000000  0.000000
# currentGameInSeries                 0.000000  0.000000  0.000000  0.000000
#
#                                      4         5         6         7        \
# target1__mean__90d__60lag           0.000000  0.000000  0.000000  0.000000
# target1__median__90d__60lag         0.000000  0.000000  0.000000  0.000000
# target1__std__90d__60lag            0.000000  0.000000  0.000000  0.000000
# target2__mean__90d__60lag           0.000000  0.000000  0.000000  0.000000
# target2__median__90d__60lag         0.000000  0.000000  0.000000  0.000000
# target2__std__90d__60lag            0.000000  0.000000  0.000000  0.000000
# target3__mean__90d__60lag           0.000000  0.000000  0.000000  0.000000
# target3__median__90d__60lag         0.000000  0.000000  0.000000  0.000000
# target3__std__90d__60lag            0.000000  0.000000  0.000000  0.000000
# target4__mean__90d__60lag           0.000000  0.000000  0.000000  0.000000
# target4__median__90d__60lag         0.000000  0.000000  0.000000  0.000000
# target4__std__90d__60lag            0.000000  0.000000  0.000000  0.000000
# battingOrder__ptvf                  0.000000  0.000000  0.000000  0.000000
# groundOuts__ptvf                    0.000000  0.000000  0.000000  0.000000
# runsScored__ptvf                    0.000000  0.000000  0.000000  0.000000
# homeRuns__ptvf                      0.000000  0.000000  0.000000  0.000000
# strikeOuts__ptvf                    0.000000  0.000000  0.000000  0.000000
# baseOnBalls__ptvf                   0.000000  0.000000  0.000000  0.000000
# intentionalWalks__ptvf              0.000000  0.000000  0.000000  0.000000
# hits__ptvf                          0.000000  0.000000  0.000000  0.000000
# hitByPitch__ptvf                    0.000000  0.000000  0.000000  0.000000
# stolenBases__ptvf                   0.000000  0.000000  0.000000  0.000000
# groundIntoTriplePlay__ptvf          0.000000  0.000000  0.000000  0.000000
# plateAppearances__ptvf              0.000000  0.000000  0.000000  0.000000
# totalBases__ptvf                    0.000000  0.000000  0.000000  0.000000
# rbi__ptvf                           0.000000  0.000000  0.000000  0.000000
# catchersInterference__ptvf          0.000000  0.000000  0.000000  0.000000
# pickoffs__ptvf                      0.000000  0.000000  0.000000  0.000000
# gamesPlayedPitching__ptvf           0.000000  0.000000  0.000000  0.000000
# gamesStartedPitching__ptvf          0.000000  0.000000  0.000000  0.000000
# completeGamesPitching__ptvf         0.000000  0.000000  0.000000  0.000000
# winsPitching__ptvf                  0.000000  0.000000  0.000000  0.000000
# lossesPitching__ptvf                0.000000  0.000000  0.000000  0.000000
# groundOutsPitching__ptvf            0.000000  0.000000  0.000000  0.000000
# runsPitching__ptvf                  0.000000  0.000000  0.000000  0.000000
# strikeOutsPitching__ptvf            0.000000  0.000000  0.000000  0.000000
# atBatsPitching__ptvf                0.000000  0.000000  0.000000  0.000000
# caughtStealingPitching__ptvf        0.000000  0.000000  0.000000  0.000000
# inningsPitched__ptvf                0.000000  0.000000  0.000000  0.000000
# saveOpportunities__ptvf             0.000000  0.000000  0.000000  0.000000
# battersFaced__ptvf                  0.000000  0.000000  0.000000  0.000000
# outsPitching__ptvf                  0.000000  0.000000  0.000000  0.000000
# balks__ptvf                         0.000000  0.000000  0.000000  0.000000
# pickoffsPitching__ptvf              0.000000  0.000000  0.000000  0.000000
# gamesFinishedPitching__ptvf         0.000000  0.000000  0.000000  0.000000
# inheritedRunners__ptvf              0.000000  0.000000  0.000000  0.000000
# catchersInterferencePitching__ptvf  0.000000  0.000000  0.000000  0.000000
# sacBuntsPitching__ptvf              0.000000  0.000000  0.000000  0.000000
# saves__ptvf                         0.000000  0.000000  0.000000  0.000000
# holds__ptvf                         0.000000  0.000000  0.000000  0.000000
# blownSaves__ptvf                    0.000000  0.000000  0.000000  0.000000
# assists__ptvf                       0.000000  0.000000  0.000000  0.000000
# putOuts__ptvf                       0.000000  0.000000  0.000000  0.000000
# chances__ptvf                       0.000000  0.000000  0.000000  0.000000
# SLG__ptvf                           0.166667  0.166667  0.166667  0.166667
# runsScored__date__maxNorm__ptvf     0.000000  0.000000  0.000000  0.000000
# homeRuns__date__maxNorm__ptvf       0.000000  0.000000  0.000000  0.000000
# hits__date__maxNorm__ptvf           0.000000  0.000000  0.000000  0.000000
# SLG__date__maxNorm__ptvf            0.500000  0.500000  0.500000  0.500000
# rbi__date__maxNorm__ptvf            0.000000  0.000000  0.000000  0.000000
# runsPitching__date__maxNorm__ptvf   0.000000  0.000000  0.000000  0.000000
# isTie                               0.000000  0.000000  0.000000  0.000000
# totalGamesVsoppTeam                 0.000000  0.000000  0.000000  0.000000
# playerTeamScore                     0.000000  0.000000  0.000000  0.000000
# playerTeamWinPctAsHome              0.000000  0.000000  0.000000  0.000000
# playerTeamWinPctAsAway              0.000000  0.000000  0.000000  0.000000
# playerTeamWintPctHist               0.000000  0.000000  0.000000  0.000000
# opponentTeamScore                   0.000000  0.000000  0.000000  0.000000
# opponentTeamWinPctAsHome            0.000000  0.000000  0.000000  0.000000
# opponentTeamWinPctAsAway            0.000000  0.000000  0.000000  0.000000
# numberOfFollowers                   0.076515  0.076515  0.076515  0.076515
# awardCount                          0.000000  0.000000  0.000000  0.000000
# teamFollowers                       0.201653  0.201653  0.201653  0.201653
# playerTeamWinpct                    0.000000  0.000000  0.000000  0.000000
# playerTeamDivisionchamp             0.000000  0.000000  0.000000  0.000000
# playerTeamDivisionleader            0.000000  0.000000  0.000000  0.000000
# playerTeamLasttenwins               0.000000  0.000000  0.000000  0.000000
# playerTeamLasttenlosses             0.000000  0.000000  0.000000  0.000000
# playerTeamXwinlosspct               0.000000  0.000000  0.000000  0.000000
# playerTeamHomewinpct                0.000000  0.000000  0.000000  0.000000
# playerTeamAwaywinpct                0.000000  0.000000  0.000000  0.000000
# playerTeamHomewinpct__Date__Ranked  0.000000  0.000000  0.000000  0.000000
# playerTeamAwaywinpct__Date__Ranked  0.000000  0.000000  0.000000  0.000000
# playerTeamWinpct__Date__Ranked      0.000000  0.000000  0.000000  0.000000
# weight                              0.641221  0.641221  0.641221  0.641221
# height                              0.562500  0.562500  0.562500  0.562500
# playerBMI                           0.473144  0.473144  0.473144  0.473144
# pstatsTime                          0.000000  0.000000  0.000000  0.000000
# playerAge                           0.862850  0.862966  0.863082  0.863198
# playerTSinceDebut                   0.861807  0.861924  0.862041  0.862158
# playerDebutAge                      0.123216  0.123216  0.123216  0.123216
# rostersTime                         0.000000  0.000000  0.000000  0.000000
# playerId                            1.000000  1.000000  1.000000  1.000000
# seasonPart                          3.000000  3.000000  3.000000  3.000000
# year                                1.000000  1.000000  1.000000  1.000000
# primaryPositionName                 3.000000  3.000000  3.000000  3.000000
# status                              3.000000  3.000000  3.000000  3.000000
# teamId                              1.000000  1.000000  1.000000  1.000000
# opponentTeamId                      0.000000  0.000000  0.000000  0.000000
# home                                0.000000  0.000000  0.000000  0.000000
# seriesDescription                   0.000000  0.000000  0.000000  0.000000
# currentGameInSeries                 0.000000  0.000000  0.000000  0.000000
#
#                                      8         9        ...      1535968  \
# target1__mean__90d__60lag           0.000000  0.000000  ...     0.005075
# target1__median__90d__60lag         0.000000  0.000000  ...     0.000189
# target1__std__90d__60lag            0.000000  0.000000  ...     0.025953
# target2__mean__90d__60lag           0.000000  0.000000  ...     0.083716
# target2__median__90d__60lag         0.000000  0.000000  ...     0.044770
# target2__std__90d__60lag            0.000000  0.000000  ...     0.224969
# target3__mean__90d__60lag           0.000000  0.000000  ...     0.006548
# target3__median__90d__60lag         0.000000  0.000000  ...     0.000459
# target3__std__90d__60lag            0.000000  0.000000  ...     0.024430
# target4__mean__90d__60lag           0.000000  0.000000  ...     0.017479
# target4__median__90d__60lag         0.000000  0.000000  ...     0.011769
# target4__std__90d__60lag            0.000000  0.000000  ...     0.042372
# battingOrder__ptvf                  0.000000  0.000000  ...     0.000000
# groundOuts__ptvf                    0.000000  0.000000  ...     0.000000
# runsScored__ptvf                    0.000000  0.000000  ...     0.000000
# homeRuns__ptvf                      0.000000  0.000000  ...     0.000000
# strikeOuts__ptvf                    0.000000  0.000000  ...     0.000000
# baseOnBalls__ptvf                   0.000000  0.000000  ...     0.000000
# intentionalWalks__ptvf              0.000000  0.000000  ...     0.000000
# hits__ptvf                          0.000000  0.000000  ...     0.000000
# hitByPitch__ptvf                    0.000000  0.000000  ...     0.000000
# stolenBases__ptvf                   0.000000  0.000000  ...     0.000000
# groundIntoTriplePlay__ptvf          0.000000  0.000000  ...     0.000000
# plateAppearances__ptvf              0.000000  0.000000  ...     0.000000
# totalBases__ptvf                    0.000000  0.000000  ...     0.000000
# rbi__ptvf                           0.000000  0.000000  ...     0.000000
# catchersInterference__ptvf          0.000000  0.000000  ...     0.000000
# pickoffs__ptvf                      0.000000  0.000000  ...     0.000000
# gamesPlayedPitching__ptvf           0.000000  0.000000  ...     0.000000
# gamesStartedPitching__ptvf          0.000000  0.000000  ...     0.000000
# completeGamesPitching__ptvf         0.000000  0.000000  ...     0.000000
# winsPitching__ptvf                  0.000000  0.000000  ...     0.000000
# lossesPitching__ptvf                0.000000  0.000000  ...     0.000000
# groundOutsPitching__ptvf            0.000000  0.000000  ...     0.000000
# runsPitching__ptvf                  0.000000  0.000000  ...     0.000000
# strikeOutsPitching__ptvf            0.000000  0.000000  ...     0.000000
# atBatsPitching__ptvf                0.000000  0.000000  ...     0.000000
# caughtStealingPitching__ptvf        0.000000  0.000000  ...     0.000000
# inningsPitched__ptvf                0.000000  0.000000  ...     0.000000
# saveOpportunities__ptvf             0.000000  0.000000  ...     0.000000
# battersFaced__ptvf                  0.000000  0.000000  ...     0.000000
# outsPitching__ptvf                  0.000000  0.000000  ...     0.000000
# balks__ptvf                         0.000000  0.000000  ...     0.000000
# pickoffsPitching__ptvf              0.000000  0.000000  ...     0.000000
# gamesFinishedPitching__ptvf         0.000000  0.000000  ...     0.000000
# inheritedRunners__ptvf              0.000000  0.000000  ...     0.000000
# catchersInterferencePitching__ptvf  0.000000  0.000000  ...     0.000000
# sacBuntsPitching__ptvf              0.000000  0.000000  ...     0.000000
# saves__ptvf                         0.000000  0.000000  ...     0.000000
# holds__ptvf                         0.000000  0.000000  ...     0.000000
# blownSaves__ptvf                    0.000000  0.000000  ...     0.000000
# assists__ptvf                       0.000000  0.000000  ...     0.000000
# putOuts__ptvf                       0.000000  0.000000  ...     0.000000
# chances__ptvf                       0.000000  0.000000  ...     0.000000
# SLG__ptvf                           0.166667  0.166667  ...     0.166667
# runsScored__date__maxNorm__ptvf     0.000000  0.000000  ...     0.000000
# homeRuns__date__maxNorm__ptvf       0.000000  0.000000  ...     0.000000
# hits__date__maxNorm__ptvf           0.000000  0.000000  ...     0.000000
# SLG__date__maxNorm__ptvf            0.500000  0.500000  ...     0.500000
# rbi__date__maxNorm__ptvf            0.000000  0.000000  ...     0.000000
# runsPitching__date__maxNorm__ptvf   0.000000  0.000000  ...     0.000000
# isTie                               0.000000  0.000000  ...     0.000000
# totalGamesVsoppTeam                 0.000000  0.000000  ...     0.000000
# playerTeamScore                     0.000000  0.000000  ...     0.000000
# playerTeamWinPctAsHome              0.000000  0.000000  ...     0.000000
# playerTeamWinPctAsAway              0.000000  0.000000  ...     0.000000
# playerTeamWintPctHist               0.000000  0.000000  ...     0.000000
# opponentTeamScore                   0.000000  0.000000  ...     0.000000
# opponentTeamWinPctAsHome            0.000000  0.000000  ...     0.000000
# opponentTeamWinPctAsAway            0.000000  0.000000  ...     0.000000
# numberOfFollowers                   0.076515  0.076515  ...     0.004301
# awardCount                          0.000000  0.000000  ...     0.000000
# teamFollowers                       0.201653  0.201653  ...     0.340670
# playerTeamWinpct                    0.000000  0.000000  ...     0.391000
# playerTeamDivisionchamp             0.000000  0.000000  ...     0.000000
# playerTeamDivisionleader            0.000000  0.000000  ...     0.000000
# playerTeamLasttenwins               0.000000  0.000000  ...     0.500000
# playerTeamLasttenlosses             0.000000  0.000000  ...     0.500000
# playerTeamXwinlosspct               0.000000  0.000000  ...     0.421000
# playerTeamHomewinpct                0.000000  0.000000  ...     0.477273
# playerTeamAwaywinpct                0.000000  0.000000  ...     0.302326
# playerTeamHomewinpct__Date__Ranked  0.000000  0.000000  ...     0.166667
# playerTeamAwaywinpct__Date__Ranked  0.000000  0.000000  ...     0.100000
# playerTeamWinpct__Date__Ranked      0.000000  0.000000  ...     0.133333
# weight                              0.641221  0.641221  ...     0.450382
# height                              0.562500  0.562500  ...     0.500000
# playerBMI                           0.473144  0.473144  ...     0.356842
# pstatsTime                          0.000000  0.000000  ...     0.057063
# playerAge                           0.863314  0.863431  ...     0.478342
# playerTSinceDebut                   0.862275  0.862392  ...     0.156681
# playerDebutAge                      0.123216  0.123216  ...     0.668945
# rostersTime                         0.000000  0.000000  ...     0.000000
# playerId                            1.000000  1.000000  ...  1187.000000
# seasonPart                          3.000000  3.000000  ...     6.000000
# year                                1.000000  1.000000  ...     4.000000
# primaryPositionName                 3.000000  3.000000  ...     6.000000
# status                              3.000000  3.000000  ...     7.000000
# teamId                              1.000000  1.000000  ...    22.000000
# opponentTeamId                      0.000000  0.000000  ...     0.000000
# home                                0.000000  0.000000  ...     0.000000
# seriesDescription                   0.000000  0.000000  ...     0.000000
# currentGameInSeries                 0.000000  0.000000  ...     0.000000
#
#                                         1535969      1535970      1535971  \
# target1__mean__90d__60lag              0.005079     0.005110     0.005150
# target1__median__90d__60lag            0.000232     0.000272     0.000279
# target1__std__90d__60lag               0.025952     0.025943     0.025932
# target2__mean__90d__60lag              0.083537     0.083403     0.082961
# target2__median__90d__60lag            0.044770     0.044770     0.044770
# target2__std__90d__60lag               0.225145     0.225285     0.225647
# target3__mean__90d__60lag              0.006559     0.006561     0.006564
# target3__median__90d__60lag            0.000497     0.000497     0.000497
# target3__std__90d__60lag               0.024422     0.024419     0.024417
# target4__mean__90d__60lag              0.017467     0.017419     0.017352
# target4__median__90d__60lag            0.011769     0.011769     0.011769
# target4__std__90d__60lag               0.042390     0.042462     0.042556
# battingOrder__ptvf                     0.000000     0.000000     0.000000
# groundOuts__ptvf                       0.000000     0.000000     0.000000
# runsScored__ptvf                       0.000000     0.000000     0.000000
# homeRuns__ptvf                         0.000000     0.000000     0.000000
# strikeOuts__ptvf                       0.000000     0.000000     0.000000
# baseOnBalls__ptvf                      0.000000     0.000000     0.000000
# intentionalWalks__ptvf                 0.000000     0.000000     0.000000
# hits__ptvf                             0.000000     0.000000     0.000000
# hitByPitch__ptvf                       0.000000     0.000000     0.000000
# stolenBases__ptvf                      0.000000     0.000000     0.000000
# groundIntoTriplePlay__ptvf             0.000000     0.000000     0.000000
# plateAppearances__ptvf                 0.000000     0.000000     0.000000
# totalBases__ptvf                       0.000000     0.000000     0.000000
# rbi__ptvf                              0.000000     0.000000     0.000000
# catchersInterference__ptvf             0.000000     0.000000     0.000000
# pickoffs__ptvf                         0.000000     0.000000     0.000000
# gamesPlayedPitching__ptvf              0.000000     0.000000     0.000000
# gamesStartedPitching__ptvf             0.000000     0.000000     0.000000
# completeGamesPitching__ptvf            0.000000     0.000000     0.000000
# winsPitching__ptvf                     0.000000     0.000000     0.000000
# lossesPitching__ptvf                   0.000000     0.000000     0.000000
# groundOutsPitching__ptvf               0.000000     0.000000     0.000000
# runsPitching__ptvf                     0.000000     0.000000     0.000000
# strikeOutsPitching__ptvf               0.000000     0.000000     0.000000
# atBatsPitching__ptvf                   0.000000     0.000000     0.000000
# caughtStealingPitching__ptvf           0.000000     0.000000     0.000000
# inningsPitched__ptvf                   0.000000     0.000000     0.000000
# saveOpportunities__ptvf                0.000000     0.000000     0.000000
# battersFaced__ptvf                     0.000000     0.000000     0.000000
# outsPitching__ptvf                     0.000000     0.000000     0.000000
# balks__ptvf                            0.000000     0.000000     0.000000
# pickoffsPitching__ptvf                 0.000000     0.000000     0.000000
# gamesFinishedPitching__ptvf            0.000000     0.000000     0.000000
# inheritedRunners__ptvf                 0.000000     0.000000     0.000000
# catchersInterferencePitching__ptvf     0.000000     0.000000     0.000000
# sacBuntsPitching__ptvf                 0.000000     0.000000     0.000000
# saves__ptvf                            0.000000     0.000000     0.000000
# holds__ptvf                            0.000000     0.000000     0.000000
# blownSaves__ptvf                       0.000000     0.000000     0.000000
# assists__ptvf                          0.000000     0.000000     0.000000
# putOuts__ptvf                          0.000000     0.000000     0.000000
# chances__ptvf                          0.000000     0.000000     0.000000
# SLG__ptvf                              0.166667     0.166667     0.166667
# runsScored__date__maxNorm__ptvf        0.000000     0.000000     0.000000
# homeRuns__date__maxNorm__ptvf          0.000000     0.000000     0.000000
# hits__date__maxNorm__ptvf              0.000000     0.000000     0.000000
# SLG__date__maxNorm__ptvf               0.500000     0.500000     0.500000
# rbi__date__maxNorm__ptvf               0.000000     0.000000     0.000000
# runsPitching__date__maxNorm__ptvf      0.000000     0.000000     0.000000
# isTie                                  0.000000     0.000000     0.000000
# totalGamesVsoppTeam                    0.000000     0.000000     0.000000
# playerTeamScore                        0.000000     0.000000     0.000000
# playerTeamWinPctAsHome                 0.000000     0.000000     0.000000
# playerTeamWinPctAsAway                 0.000000     0.000000     0.000000
# playerTeamWintPctHist                  0.000000     0.000000     0.000000
# opponentTeamScore                      0.000000     0.000000     0.000000
# opponentTeamWinPctAsHome               0.000000     0.000000     0.000000
# opponentTeamWinPctAsAway               0.000000     0.000000     0.000000
# numberOfFollowers                      0.004301     0.004301     0.004301
# awardCount                             0.000000     0.000000     0.000000
# teamFollowers                          0.340670     0.340670     0.340670
# playerTeamWinpct                       0.398000     0.393000     0.389000
# playerTeamDivisionchamp                0.000000     0.000000     0.000000
# playerTeamDivisionleader               0.000000     0.000000     0.000000
# playerTeamLasttenwins                  0.500000     0.400000     0.400000
# playerTeamLasttenlosses                0.500000     0.600000     0.600000
# playerTeamXwinlosspct                  0.421000     0.421000     0.421000
# playerTeamHomewinpct                   0.488889     0.478261     0.468085
# playerTeamAwaywinpct                   0.302326     0.302326     0.302326
# playerTeamHomewinpct__Date__Ranked     0.266667     0.166667     0.150000
# playerTeamAwaywinpct__Date__Ranked     0.116667     0.100000     0.100000
# playerTeamWinpct__Date__Ranked         0.133333     0.133333     0.133333
# weight                                 0.450382     0.450382     0.450382
# height                                 0.500000     0.500000     0.500000
# playerBMI                              0.356842     0.356842     0.356842
# pstatsTime                             0.057998     0.058934     0.059869
# playerAge                              0.478458     0.478574     0.478690
# playerTSinceDebut                      0.156798     0.156916     0.157033
# playerDebutAge                         0.668945     0.668945     0.668945
# rostersTime                            0.000000     0.000000     0.000000
# playerId                            1187.000000  1187.000000  1187.000000
# seasonPart                             6.000000     6.000000     6.000000
# year                                   4.000000     4.000000     4.000000
# primaryPositionName                    6.000000     6.000000     6.000000
# status                                 7.000000     7.000000     7.000000
# teamId                                22.000000    22.000000    22.000000
# opponentTeamId                         0.000000     0.000000     0.000000
# home                                   0.000000     0.000000     0.000000
# seriesDescription                      0.000000     0.000000     0.000000
# currentGameInSeries                    0.000000     0.000000     0.000000
#
#                                         1535972      1535973      1535974  \
# target1__mean__90d__60lag              0.005157     0.005157     0.005158
# target1__median__90d__60lag            0.000290     0.000290     0.000290
# target1__std__90d__60lag               0.025930     0.025930     0.025929
# target2__mean__90d__60lag              0.082719     0.082305     0.082099
# target2__median__90d__60lag            0.044770     0.044770     0.044770
# target2__std__90d__60lag               0.225866     0.226191     0.226384
# target3__mean__90d__60lag              0.006566     0.006567     0.006568
# target3__median__90d__60lag            0.000497     0.000497     0.000497
# target3__std__90d__60lag               0.024415     0.024414     0.024414
# target4__mean__90d__60lag              0.017320     0.017233     0.017164
# target4__median__90d__60lag            0.011769     0.011769     0.011769
# target4__std__90d__60lag               0.042591     0.042706     0.042797
# battingOrder__ptvf                     0.000000     0.000000     0.000000
# groundOuts__ptvf                       0.000000     0.000000     0.000000
# runsScored__ptvf                       0.000000     0.000000     0.000000
# homeRuns__ptvf                         0.000000     0.000000     0.000000
# strikeOuts__ptvf                       0.000000     0.000000     0.000000
# baseOnBalls__ptvf                      0.000000     0.000000     0.000000
# intentionalWalks__ptvf                 0.000000     0.000000     0.000000
# hits__ptvf                             0.000000     0.000000     0.000000
# hitByPitch__ptvf                       0.000000     0.000000     0.000000
# stolenBases__ptvf                      0.000000     0.000000     0.000000
# groundIntoTriplePlay__ptvf             0.000000     0.000000     0.000000
# plateAppearances__ptvf                 0.000000     0.000000     0.000000
# totalBases__ptvf                       0.000000     0.000000     0.000000
# rbi__ptvf                              0.000000     0.000000     0.000000
# catchersInterference__ptvf             0.000000     0.000000     0.000000
# pickoffs__ptvf                         0.000000     0.000000     0.000000
# gamesPlayedPitching__ptvf              0.000000     0.000000     0.000000
# gamesStartedPitching__ptvf             0.000000     0.000000     0.000000
# completeGamesPitching__ptvf            0.000000     0.000000     0.000000
# winsPitching__ptvf                     0.000000     0.000000     0.000000
# lossesPitching__ptvf                   0.000000     0.000000     0.000000
# groundOutsPitching__ptvf               0.000000     0.000000     0.000000
# runsPitching__ptvf                     0.000000     0.000000     0.000000
# strikeOutsPitching__ptvf               0.000000     0.000000     0.000000
# atBatsPitching__ptvf                   0.000000     0.000000     0.000000
# caughtStealingPitching__ptvf           0.000000     0.000000     0.000000
# inningsPitched__ptvf                   0.000000     0.000000     0.000000
# saveOpportunities__ptvf                0.000000     0.000000     0.000000
# battersFaced__ptvf                     0.000000     0.000000     0.000000
# outsPitching__ptvf                     0.000000     0.000000     0.000000
# balks__ptvf                            0.000000     0.000000     0.000000
# pickoffsPitching__ptvf                 0.000000     0.000000     0.000000
# gamesFinishedPitching__ptvf            0.000000     0.000000     0.000000
# inheritedRunners__ptvf                 0.000000     0.000000     0.000000
# catchersInterferencePitching__ptvf     0.000000     0.000000     0.000000
# sacBuntsPitching__ptvf                 0.000000     0.000000     0.000000
# saves__ptvf                            0.000000     0.000000     0.000000
# holds__ptvf                            0.000000     0.000000     0.000000
# blownSaves__ptvf                       0.000000     0.000000     0.000000
# assists__ptvf                          0.000000     0.000000     0.000000
# putOuts__ptvf                          0.000000     0.000000     0.000000
# chances__ptvf                          0.000000     0.000000     0.000000
# SLG__ptvf                              0.166667     0.166667     0.166667
# runsScored__date__maxNorm__ptvf        0.000000     0.000000     0.000000
# homeRuns__date__maxNorm__ptvf          0.000000     0.000000     0.000000
# hits__date__maxNorm__ptvf              0.000000     0.000000     0.000000
# SLG__date__maxNorm__ptvf               0.500000     0.500000     0.500000
# rbi__date__maxNorm__ptvf               0.000000     0.000000     0.000000
# runsPitching__date__maxNorm__ptvf      0.000000     0.000000     0.000000
# isTie                                  0.000000     0.000000     0.000000
# totalGamesVsoppTeam                    0.000000     0.000000     0.000000
# playerTeamScore                        0.000000     0.000000     0.000000
# playerTeamWinPctAsHome                 0.000000     0.000000     0.000000
# playerTeamWinPctAsAway                 0.000000     0.000000     0.000000
# playerTeamWintPctHist                  0.000000     0.000000     0.000000
# opponentTeamScore                      0.000000     0.000000     0.000000
# opponentTeamWinPctAsHome               0.000000     0.000000     0.000000
# opponentTeamWinPctAsAway               0.000000     0.000000     0.000000
# numberOfFollowers                      0.004301     0.004301     0.004301
# awardCount                             0.000000     0.000000     0.000000
# teamFollowers                          0.340670     0.340670     0.340670
# playerTeamWinpct                       0.389000     0.389000     0.389000
# playerTeamDivisionchamp                0.000000     0.000000     0.000000
# playerTeamDivisionleader               0.000000     0.000000     0.000000
# playerTeamLasttenwins                  0.400000     0.400000     0.400000
# playerTeamLasttenlosses                0.600000     0.600000     0.600000
# playerTeamXwinlosspct                  0.421000     0.421000     0.421000
# playerTeamHomewinpct                   0.468085     0.468085     0.468085
# playerTeamAwaywinpct                   0.302326     0.302326     0.302326
# playerTeamHomewinpct__Date__Ranked     0.150000     0.150000     0.150000
# playerTeamAwaywinpct__Date__Ranked     0.100000     0.100000     0.100000
# playerTeamWinpct__Date__Ranked         0.133333     0.133333     0.133333
# weight                                 0.450382     0.450382     0.450382
# height                                 0.500000     0.500000     0.500000
# playerBMI                              0.356842     0.356842     0.356842
# pstatsTime                             0.060804     0.061740     0.062675
# playerAge                              0.478806     0.478922     0.479038
# playerTSinceDebut                      0.157150     0.157267     0.157384
# playerDebutAge                         0.668945     0.668945     0.668945
# rostersTime                            0.000000     0.000000     0.000000
# playerId                            1187.000000  1187.000000  1187.000000
# seasonPart                             1.000000     1.000000     1.000000
# year                                   4.000000     4.000000     4.000000
# primaryPositionName                    6.000000     6.000000     6.000000
# status                                 7.000000     7.000000     7.000000
# teamId                                22.000000    22.000000    22.000000
# opponentTeamId                         0.000000     0.000000     0.000000
# home                                   0.000000     0.000000     0.000000
# seriesDescription                      0.000000     0.000000     0.000000
# currentGameInSeries                    0.000000     0.000000     0.000000
#
#                                         1535975      1535976      1535977
# target1__mean__90d__60lag              0.005159     0.005159     0.005160
# target1__median__90d__60lag            0.000290     0.000290     0.000290
# target1__std__90d__60lag               0.025929     0.025929     0.025929
# target2__mean__90d__60lag              0.081926     0.081724     0.081436
# target2__median__90d__60lag            0.044770     0.044770     0.044770
# target2__std__90d__60lag               0.226552     0.226749     0.227012
# target3__mean__90d__60lag              0.006569     0.006570     0.006233
# target3__median__90d__60lag            0.000497     0.000497     0.000459
# target3__std__90d__60lag               0.024413     0.024412     0.024027
# target4__mean__90d__60lag              0.017056     0.017061     0.017044
# target4__median__90d__60lag            0.011769     0.011769     0.011769
# target4__std__90d__60lag               0.042925     0.042916     0.042942
# battingOrder__ptvf                     0.000000     0.000000     0.000000
# groundOuts__ptvf                       0.000000     0.000000     0.000000
# runsScored__ptvf                       0.000000     0.000000     0.000000
# homeRuns__ptvf                         0.000000     0.000000     0.000000
# strikeOuts__ptvf                       0.000000     0.000000     0.000000
# baseOnBalls__ptvf                      0.000000     0.000000     0.000000
# intentionalWalks__ptvf                 0.000000     0.000000     0.000000
# hits__ptvf                             0.000000     0.000000     0.000000
# hitByPitch__ptvf                       0.000000     0.000000     0.000000
# stolenBases__ptvf                      0.000000     0.000000     0.000000
# groundIntoTriplePlay__ptvf             0.000000     0.000000     0.000000
# plateAppearances__ptvf                 0.000000     0.000000     0.000000
# totalBases__ptvf                       0.000000     0.000000     0.000000
# rbi__ptvf                              0.000000     0.000000     0.000000
# catchersInterference__ptvf             0.000000     0.000000     0.000000
# pickoffs__ptvf                         0.000000     0.000000     0.000000
# gamesPlayedPitching__ptvf              0.000000     0.000000     0.000000
# gamesStartedPitching__ptvf             0.000000     0.000000     0.000000
# completeGamesPitching__ptvf            0.000000     0.000000     0.000000
# winsPitching__ptvf                     0.000000     0.000000     0.000000
# lossesPitching__ptvf                   0.000000     0.000000     0.000000
# groundOutsPitching__ptvf               0.000000     0.000000     0.000000
# runsPitching__ptvf                     0.000000     0.000000     0.000000
# strikeOutsPitching__ptvf               0.000000     0.000000     0.000000
# atBatsPitching__ptvf                   0.000000     0.000000     0.000000
# caughtStealingPitching__ptvf           0.000000     0.000000     0.000000
# inningsPitched__ptvf                   0.000000     0.000000     0.000000
# saveOpportunities__ptvf                0.000000     0.000000     0.000000
# battersFaced__ptvf                     0.000000     0.000000     0.000000
# outsPitching__ptvf                     0.000000     0.000000     0.000000
# balks__ptvf                            0.000000     0.000000     0.000000
# pickoffsPitching__ptvf                 0.000000     0.000000     0.000000
# gamesFinishedPitching__ptvf            0.000000     0.000000     0.000000
# inheritedRunners__ptvf                 0.000000     0.000000     0.000000
# catchersInterferencePitching__ptvf     0.000000     0.000000     0.000000
# sacBuntsPitching__ptvf                 0.000000     0.000000     0.000000
# saves__ptvf                            0.000000     0.000000     0.000000
# holds__ptvf                            0.000000     0.000000     0.000000
# blownSaves__ptvf                       0.000000     0.000000     0.000000
# assists__ptvf                          0.000000     0.000000     0.000000
# putOuts__ptvf                          0.000000     0.000000     0.000000
# chances__ptvf                          0.000000     0.000000     0.000000
# SLG__ptvf                              0.166667     0.166667     0.166667
# runsScored__date__maxNorm__ptvf        0.000000     0.000000     0.000000
# homeRuns__date__maxNorm__ptvf          0.000000     0.000000     0.000000
# hits__date__maxNorm__ptvf              0.000000     0.000000     0.000000
# SLG__date__maxNorm__ptvf               0.500000     0.500000     0.500000
# rbi__date__maxNorm__ptvf               0.000000     0.000000     0.000000
# runsPitching__date__maxNorm__ptvf      0.000000     0.000000     0.000000
# isTie                                  0.000000     0.000000     0.000000
# totalGamesVsoppTeam                    0.000000     0.000000     0.000000
# playerTeamScore                        0.000000     0.000000     0.000000
# playerTeamWinPctAsHome                 0.000000     0.000000     0.000000
# playerTeamWinPctAsAway                 0.000000     0.000000     0.000000
# playerTeamWintPctHist                  0.000000     0.000000     0.000000
# opponentTeamScore                      0.000000     0.000000     0.000000
# opponentTeamWinPctAsHome               0.000000     0.000000     0.000000
# opponentTeamWinPctAsAway               0.000000     0.000000     0.000000
# numberOfFollowers                      0.004301     0.004301     0.004301
# awardCount                             0.000000     0.000000     0.000000
# teamFollowers                          0.340670     0.340670     0.340670
# playerTeamWinpct                       0.389000     0.385000     0.385000
# playerTeamDivisionchamp                0.000000     0.000000     0.000000
# playerTeamDivisionleader               0.000000     0.000000     0.000000
# playerTeamLasttenwins                  0.400000     0.300000     0.300000
# playerTeamLasttenlosses                0.600000     0.700000     0.700000
# playerTeamXwinlosspct                  0.421000     0.421000     0.421000
# playerTeamHomewinpct                   0.468085     0.468085     0.468085
# playerTeamAwaywinpct                   0.302326     0.295455     0.295455
# playerTeamHomewinpct__Date__Ranked     0.150000     0.150000     0.150000
# playerTeamAwaywinpct__Date__Ranked     0.100000     0.100000     0.100000
# playerTeamWinpct__Date__Ranked         0.133333     0.116667     0.100000
# weight                                 0.450382     0.450382     0.450382
# height                                 0.500000     0.500000     0.500000
# playerBMI                              0.356842     0.356842     0.356842
# pstatsTime                             0.063611     0.064546     0.065482
# playerAge                              0.479155     0.479271     0.479387
# playerTSinceDebut                      0.157501     0.157618     0.157735
# playerDebutAge                         0.668945     0.668945     0.668945
# rostersTime                            0.000000     0.000000     0.000000
# playerId                            1187.000000  1187.000000  1187.000000
# seasonPart                             7.000000     7.000000     7.000000
# year                                   4.000000     4.000000     4.000000
# primaryPositionName                    6.000000     6.000000     6.000000
# status                                 7.000000     7.000000     7.000000
# teamId                                22.000000    22.000000    22.000000
# opponentTeamId                         0.000000     0.000000     0.000000
# home                                   0.000000     0.000000     0.000000
# seriesDescription                      0.000000     0.000000     0.000000
# currentGameInSeries                    0.000000     0.000000     0.000000
#
# [102 rows x 1535978 columns]

# %%
# change the dtypes of the target (pytorch likes float32 and not float64)
df[target_cols] = df[target_cols].astype(np.float32)

# %%
train_idx.shape
# Out:
# (1535978,)

# %%
train_idx.shape
# Out:
# (1535978,)

# %%
train_data = sp.filter(features, train_idx)

raw_train_df = sp.filter(df, train_idx)

# %%
valid_data = sp.filter(features, valid_idx)
raw_valid_df = sp.filter(df, valid_idx)

# %%
train_data.shape, raw_train_df.shape
# Out:
# ((1407782, 102), (1407782, 98))

# %%
valid_data.shape, raw_valid_df.shape
# Out:
# ((128196, 102), (128196, 98))

# %%
# add the target to features ds
train_data[target_cols + ['date']] = raw_train_df[target_cols + ['date']]
valid_data[target_cols + ['date']] = raw_valid_df[target_cols + ['date']]

# %% [markdown]
# ### modeling

# %%
time_features = ['battingOrder', 'gamesPlayedBatting', 'flyOuts', 'groundOuts',
       'runsScored', 'doubles', 'triples', 'homeRuns', 'strikeOuts',
       'baseOnBalls', 'intentionalWalks', 'hits', 'hitByPitch', 'atBats',
       'caughtStealing', 'stolenBases', 'groundIntoDoublePlay',
       'groundIntoTriplePlay', 'plateAppearances', 'totalBases', 'rbi',
       'leftOnBase', 'sacBunts', 'sacFlies', 'catchersInterference',
       'pickoffs', 'gamesPlayedPitching', 'gamesStartedPitching',
       'completeGamesPitching', 'shutoutsPitching', 'winsPitching',
       'lossesPitching', 'flyOutsPitching', 'airOutsPitching',
       'groundOutsPitching', 'runsPitching', 'doublesPitching',
       'triplesPitching', 'homeRunsPitching', 'strikeOutsPitching',
       'baseOnBallsPitching', 'intentionalWalksPitching', 'hitsPitching',
       'hitByPitchPitching', 'atBatsPitching', 'caughtStealingPitching',
       'stolenBasesPitching', 'inningsPitched', 'saveOpportunities',
       'earnedRuns', 'battersFaced', 'outsPitching', 'pitchesThrown', 'balls',
       'strikes', 'hitBatsmen', 'balks', 'wildPitches', 'pickoffsPitching',
       'rbiPitching', 'gamesFinishedPitching', 'inheritedRunners',
       'inheritedRunnersScored', 'catchersInterferencePitching',
       'sacBuntsPitching', 'sacFliesPitching', 'saves', 'holds', 'blownSaves',
       'assists', 'putOuts', 'errors', 'chances', 'isTie',
       'gamesInSeries', 'playerTeamWins', 'playerTeamLosses',
       'playerTeamWinPct', 'playerTeamScore', 'opponentTeamWins',
       'opponentTeamLosses', 'opponentTeamWinPct', 'opponentTeamScore',
       'teamScoreDiff']

time_features = [f2 for f2 in features.columns
                 if any([f2.startswith(f) for f in time_features ])]

# %%
static_features = features.columns.drop(categories + time_features).to_list()

# %%
static_features
# Out:
# ['target1__mean__90d__60lag',
#  'target1__median__90d__60lag',
#  'target1__std__90d__60lag',
#  'target2__mean__90d__60lag',
#  'target2__median__90d__60lag',
#  'target2__std__90d__60lag',
#  'target3__mean__90d__60lag',
#  'target3__median__90d__60lag',
#  'target3__std__90d__60lag',
#  'target4__mean__90d__60lag',
#  'target4__median__90d__60lag',
#  'target4__std__90d__60lag',
#  'SLG__ptvf',
#  'SLG__date__maxNorm__ptvf',
#  'totalGamesVsoppTeam',
#  'playerTeamWintPctHist',
#  'numberOfFollowers',
#  'awardCount',
#  'teamFollowers',
#  'playerTeamWinpct',
#  'playerTeamDivisionchamp',
#  'playerTeamDivisionleader',
#  'playerTeamLasttenwins',
#  'playerTeamLasttenlosses',
#  'playerTeamXwinlosspct',
#  'playerTeamHomewinpct',
#  'playerTeamAwaywinpct',
#  'playerTeamHomewinpct__Date__Ranked',
#  'playerTeamAwaywinpct__Date__Ranked',
#  'playerTeamWinpct__Date__Ranked',
#  'weight',
#  'height',
#  'playerBMI',
#  'pstatsTime',
#  'playerAge',
#  'playerTSinceDebut',
#  'playerDebutAge',
#  'rostersTime']

# %%
categories
# Out:
# ['playerId',
#  'seasonPart',
#  'year',
#  'primaryPositionName',
#  'status',
#  'teamId',
#  'opponentTeamId',
#  'home',
#  'seriesDescription',
#  'currentGameInSeries']

# %%
from omegaconf import OmegaConf
hp = {'bptt': 1,
      'epochs': 10,
      'batch_size': 512,
      'max_emb_sz': 20,
      'hidden_dim': 16,
      'encoder_dim': 128,
      'emb_dropout': 0.2,
      'dropout': 0.2,
      'lr': 0.001,
      'wd': 3e-5}

real_data_config = {'hp': hp,
                    'seed': 2021,
         'static_features': static_features,
          'categories': categories,
          'time_features': time_features,
          'target_cols': target_cols}
real_data_config = OmegaConf.create(real_data_config)

# %%
from train.lstm import run_lstm
# Out:
# /home/med/anaconda3/envs/mlb/lib/python3.8/site-packages/pytorch_lightning/metrics/__init__.py:43: LightningDeprecationWarning: `pytorch_lightning.metrics.*` module has been renamed to `torchmetrics.*` and split off to its own package (https://github.com/PyTorchLightning/metrics) since v1.3 and will be removed in v1.5
#   rank_zero_deprecation(

# %%
output = run_lstm(real_data_config, train_data, valid_data)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name         | Type           | Params
# ------------------------------------------------
# 0 | emb          | EmbeddingLayer | 24.2 K
# 1 | net          | LSTM           | 4.6 K
# 2 | output_layer | Sequential     | 13.6 K
# ------------------------------------------------
# 42.4 K    Trainable params
# 0         Non-trainable params
# 42.4 K    Total params
# 0.170     Total estimated model params size (MB)
# LstmModel(
#   (emb): EmbeddingLayer(
#     (dropout): Dropout(p=0.2, inplace=False)
#     (emb): ModuleDict(
#       (playerId): Embedding(1188, 20)
#       (seasonPart): Embedding(8, 2)
#       (year): Embedding(5, 2)
#       (primaryPositionName): Embedding(10, 3)
#       (status): Embedding(15, 3)
#       (teamId): Embedding(32, 5)
#       (opponentTeamId): Embedding(34, 5)
#       (home): Embedding(4, 1)
#       (seriesDescription): Embedding(8, 2)
#       (currentGameInSeries): Embedding(9, 2)
#     )
#   )
#   (net): LSTM(54, 16, batch_first=True)
#   (output_layer): Sequential(
#     (0): Linear(in_features=99, out_features=128, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=128, out_features=4, bias=True)
#   )
# )
# Validation sanity check: 0it [00:00, ?it/s]
# /home/med/anaconda3/envs/mlb/lib/python3.8/site-packages/pytorch_lightning/core/step_result.py:115: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   value = torch.tensor(value, device=device, dtype=torch.float)
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
from train.core import predict_recursive, Ensemble
ensemble = Ensemble([output],
                    pipeline)

# %%
# %%time
# raw_train_fr = raw_train_df[df.columns].copy()

# recursive_prediction = []
# for date, val_date_df in raw_valid_df.groupby('date'):
#     val_date_df = val_date_df[df.columns].reset_index(drop=True)
#     _recurive_pred, raw_train_fr = predict_recursive(val_date_df,
#                                                      raw_train_fr,
#                                                      ensemble,
#                                                      n_days=90 + 60 + 10,
#                                                      target_cols=target_cols)
#     recursive_prediction.append(_recurive_pred)

# recursive_prediction = pd.concat(recursive_prediction, ignore_index=True)
# recursive_prediction.sort_values(['playerId', 'date'], inplace=True)
# recursive_prediction.reset_index(drop=True, inplace=True)
# recursive_prediction.rename(columns={f: f.replace('target', 'yhat')
#                                      for f in target_cols}, inplace=True)
# recursive_prediction[target_cols] = raw_valid_df[target_cols].to_numpy()

# %%
from evaluate.metrics import compute_metrics

# %%
valid_test_prediction = pd.DataFrame(output.prediction, columns=['yhat1', 'yhat2', 'yhat3', 'yhat4'])

valid_test_prediction[pp_cols] = raw_valid_df[pp_cols]

# %%
is_test_pred = valid_test_prediction['date'] >= '2021-05-01'

valid_prediction, test_prediction = (valid_test_prediction.loc[~is_test_pred, :],
                                     valid_test_prediction.loc[is_test_pred, :])

# %%
# valid_rc_prediction, test_rc_prediction = (recursive_prediction.loc[~is_test_pred, :],
#                                            recursive_prediction.loc[is_test_pred, :])

# %%
# metrics from 2021-03-01 up to 2021-04-30
compute_metrics(valid_test_prediction)
# Out:
# {'mae_mean': 1.3350189,
#  'mae_1': 1.0669042,
#  'mae_2': 2.0582983,
#  'mae_3': 0.85222656,
#  'mae_4': 1.3626462}

# %%
# metrics from 2021-03-01 up to 2021-03-31
compute_metrics(valid_prediction)
# Out:
# {'mae_mean': 1.5263585,
#  'mae_1': 1.1786147,
#  'mae_2': 2.3978095,
#  'mae_3': 0.9377938,
#  'mae_4': 1.5912162}

# %%
compute_metrics(test_prediction[test_prediction['date'].between('2021-05-01', '2021-06-01')])
# Out:
# {'mae_mean': 1.3665464,
#  'mae_1': 1.0967832,
#  'mae_2': 2.1868427,
#  'mae_3': 0.883537,
#  'mae_4': 1.2990229}

# %%
# metrics from 2021-04-01 up to 2021-04-30
compute_metrics(test_prediction)
# Out:
# {'mae_mean': 1.2614267,
#  'mae_1': 1.0239385,
#  'mae_2': 1.9277172,
#  'mae_3': 0.81931615,
#  'mae_4': 1.2747346}

# %% [markdown]
# from omegaconf import OmegaConf
# hp = {'bptt': 14,
#       'epochs': 10,
#       'batch_size': 512,
#       'max_emb_sz': 20,
#       'hidden_dim': 16,
#       'encoder_dim': 128,
#       'emb_dropout': 0.2,
#       'dropout': 0.2,
#       'lr': 0.001,
#       'wd': 3e-5}
#
# {'mae_mean': 1.4912145,
#  'mae_1': 1.1684885,
#  'mae_2': 2.2605271,
#  'mae_3': 0.9525842,
#  'mae_4': 1.5832579}

# %%
# # metrics from 2021-03-01 up to 2021-04-30
# compute_metrics(recursive_prediction)

# %%
# # metrics from 2021-03-01 up to 2021-03-31
# compute_metrics(valid_rc_prediction)

# %%
# # metrics from 2021-04-01 up to 2021-04-30
# compute_metrics(test_rc_prediction)

# %%
def plot_pred(df, playerId, index=1):
    pdf = df.query(f'playerId == {playerId}')
    
    f, ax = plt.subplots(1, 1, figsize=(20, 5))
    
    tname = f'target{index}'
    yhat_name = f'yhat{index}'
    
    ax.plot('date', tname, '-o', data=pdf, label=tname)
    ax.plot('date', yhat_name, '-o', data=pdf, label=tname)
    
    ax.legend()

# %%
def feature_importance(features, model):
    fi = pd.DataFrame({'feature': features, 'importance': model.feature_importances_})
    fi.sort_values(by='importance', ascending=False, inplace=True)
    return fi

def compute_fi(features, models):
    fi = [feature_importance(features, _model).assign(target=f'target{target+1}')
      for target, _model in enumerate(models)]
    fi = pd.concat(fi)
    fi = fi.pivot('feature', 'target', 'importance')
    fi = fi * 100 / fi.sum()
    fi['mean'] = fi.mean(axis=1)
    fi.sort_values(by='mean', ascending=False, inplace=True)
    return fi

# %%
for index in range(1, 5):
    plot_pred(valid_test_prediction, playerId=660271, index=index)

# %%
model = output.model

# %%
from data.dataset import PlayerDataset

# %%
_index = (raw_valid_df['playerId']== 660271)
inference_data = valid_data[_index].reset_index(drop=True)

# %%
from torch.utils.data import DataLoader
from copy import deepcopy

# %%
valid_ds = PlayerDataset.from_df(inference_data, 
                                      features=static_features,
                                      time_features=time_features,
                                      categories=categories,
                                      target=target_cols,
                                      bptt=hp['bptt'])
valid_dl = DataLoader(valid_ds, batch_size=512,
                     shuffle=False, num_workers=4)

# %%
batch = next(iter(valid_dl))
hidden_state = model.init_hidden_state(len(batch['features']))

# %%
timeft, (final_state, cell_state) = model.net(batch['timeft'],hidden_state)

# %%
timeft = timeft.detach().cpu().numpy()

# %%
no_past_batch = deepcopy(batch)

# %%
no_past_batch['timeft'] = no_past_batch['timeft'][:, [-1], :]

# %%
prediction = model(**batch)
no_past_prediction = model(**no_past_batch)

# %%
prediction.shape, no_past_prediction.shape

# %%
prediction = prediction.detach().cpu().numpy()
no_past_prediction = no_past_prediction.detach().cpu().numpy()

# %%
def plot_single_batch(batch_ft, raw_ft):
    pass

# %%
batch_index = -1

# %%
batch_ft = timeft[batch_index]

# %%
raw_ft = batch['timeft'][batch_index]

# %%
plt.figure(figsize=(20, 5))
for day in range(raw_ft.shape[0]):
    plt.plot(raw_ft[:, day])

# %%
plt.figure(figsize=(20, 5))
for day in range(batch_ft.shape[0]):
    plt.plot(batch_ft[:, day])

# %%
for i in range(4):
    plt.figure(figsize=(20, 5))
    plt.plot(batch['target'].detach().cpu().numpy()[:, i], '-o',
             label='target')
    plt.plot(prediction[:, i], '-o',
             label='with past')
    plt.plot(no_past_prediction[:, i],
             '-o',
             label='no past')
    plt.legend()

# %%
# is_playing = raw_valid_df.loc[:, time_features].drop('AwardWinner', axis=1).std(axis=1).notna()

# %%
# not_playing = raw_valid_df.loc[:, time_features].drop('AwardWinner', axis=1).isna().all(axis=1)

# %%
# compute_metrics(recursive_prediction.loc[not_playing])

# %%
# compute_metrics(recursive_prediction.loc[~not_playing])
